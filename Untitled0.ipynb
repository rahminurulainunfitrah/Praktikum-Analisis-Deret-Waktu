# %% [markdown]
# <a href="https://colab.research.google.com/github/rahminurulainunfitrah/Praktikum-Analisis-Deret-Waktu/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Praktikum 1
a=1
b=2
a+b
# Out:
# 3
